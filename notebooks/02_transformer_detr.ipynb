# %% [markdown]
# # Transformer · DETR
# This thin notebook loads the same protocol as every family. No result is embedded.

# %%
from aerial_benchmark.config import load_config, validate_config

config = load_config("../configs/transformer.yaml")
validate_config(config)
config
