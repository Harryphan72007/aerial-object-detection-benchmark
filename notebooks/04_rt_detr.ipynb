# %% [markdown]
# # Real-time Transformer · RT-DETR
# Resolve the common 50-epoch, three-seed protocol before connecting the Hugging Face adapter.

# %%
from aerial_benchmark.config import load_config, validate_config

config = load_config("../configs/rt_detr.yaml")
validate_config(config)
config
