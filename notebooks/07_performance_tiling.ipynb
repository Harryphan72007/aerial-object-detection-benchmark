# %% [markdown]
# # 07 · Generate performance-track training tiles
# Creates versioned tile annotations and a complete decision manifest without modifying source COCO data.

# %%
TILE_VERSION = "v1"
START_TILING = False

# %%
from pathlib import Path
from src.utils.serialization import read_yaml
REPO_PATH = Path.cwd()
config = read_yaml(REPO_PATH / "configs" / "performance" / "tiling_v1.yaml")
sliced_config = read_yaml(REPO_PATH / "configs" / "performance" / "sliced_inference_v1.yaml")
result = {"preview": not START_TILING, "tile_version": TILE_VERSION, "config": config, "sliced_inference": sliced_config}
result
