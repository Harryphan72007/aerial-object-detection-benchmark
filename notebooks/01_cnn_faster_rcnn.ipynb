# %% [markdown]
# # CNN · Faster R-CNN
# Resolve the shared protocol first. Training stays disabled until an exact checkpoint and adapter are reviewed.

# %%
from aerial_benchmark.config import load_config, validate_config

config = load_config("../configs/cnn.yaml")
validate_config(config)
config
