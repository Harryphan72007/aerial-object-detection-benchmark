# %% [markdown]
# # Vision Mamba · Vim
# The HUST-VL Vim source is the planned Apache-2.0 backbone. NVIDIA MambaVision is excluded due to noncommercial terms.

# %%
from aerial_benchmark.config import load_config, validate_config

config = load_config("../configs/vision_mamba.yaml")
validate_config(config)
config
